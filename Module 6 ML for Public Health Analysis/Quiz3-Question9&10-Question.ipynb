# %% [markdown]
# ## Heart Disease Prediction— Multiclass Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, accuracy_score

# %%
# import the heart disease dataset
dataset = "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"

column_names =  ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','class']

# read the csv
dataset = pd.read_csv(dataset, names=column_names)

# remove missing data with "?"
df = dataset[~dataset.isin(['?'])]

#drop rows with NaN values from DataFrame
df = df.dropna(axis=0)

# checking data type of the dataframe
print (df.dtypes)
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
# transform data to numeric because ca and thal are object datatypes
data = df.apply(pd.to_numeric)
print(data.dtypes)
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# class         int64
# dtype: object

# %%
# plot histograms for each variable
data.hist(figsize = (15, 15))
plt.show()

# %%
# create X and Y datasets for training
X = data.iloc[:,0:13]
y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,shuffle = False, random_state=90)

# There are 4 classes so we need to one-hot encode them
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=13, kernel_initializer='normal', activation='relu'))
model.add(Dense(8, kernel_initializer='normal', activation='relu'))
model.add(Dense(4, kernel_initializer='normal', activation='relu'))
model.add(Dense(5, activation='softmax'))

filepath="CNN_Model-{epoch:02d}-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
train_model = model.fit(X_train, y_train, epochs=60, batch_size=8, verbose = 1, validation_data=(X_test,y_test),callbacks=[callbacks_list])
# Out:
# Epoch 1/60
#  1/30 [>.............................] - ETA: 18s - loss: 1.6254 - accuracy: 0.1250
# Epoch 00001: val_accuracy improved from -inf to 0.48333, saving model to CNN_Model-01-0.48.h5
# 30/30 [==============================] - 1s 12ms/step - loss: 1.5482 - accuracy: 0.4768 - val_loss: 1.4624 - val_accuracy: 0.4833
# Epoch 2/60
# 26/30 [=========================>....] - ETA: 0s - loss: 1.3214 - accuracy: 0.5481
# Epoch 00002: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3139 - accuracy: 0.5527 - val_loss: 1.3496 - val_accuracy: 0.4833
# Epoch 3/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.7030 - accuracy: 0.3750
# Epoch 00003: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2839 - accuracy: 0.5527 - val_loss: 1.3324 - val_accuracy: 0.4833
# Epoch 4/60
# 29/30 [============================>.] - ETA: 0s - loss: 1.2720 - accuracy: 0.5474
# Epoch 00004: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2628 - accuracy: 0.5527 - val_loss: 1.3275 - val_accuracy: 0.4833
# Epoch 5/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.4006 - accuracy: 0.5000
# Epoch 00005: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2465 - accuracy: 0.5527 - val_loss: 1.3262 - val_accuracy: 0.4833
# Epoch 6/60
# 25/30 [========================>.....] - ETA: 0s - loss: 1.2431 - accuracy: 0.5500
# Epoch 00006: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2341 - accuracy: 0.5527 - val_loss: 1.3164 - val_accuracy: 0.4833
# Epoch 7/60
# 24/30 [=======================>......] - ETA: 0s - loss: 1.1960 - accuracy: 0.5625
# Epoch 00007: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2229 - accuracy: 0.5527 - val_loss: 1.3163 - val_accuracy: 0.4833
# Epoch 8/60
# 25/30 [========================>.....] - ETA: 0s - loss: 1.2361 - accuracy: 0.5400
# Epoch 00008: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2080 - accuracy: 0.5527 - val_loss: 1.3260 - val_accuracy: 0.4833
# Epoch 9/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.3575 - accuracy: 0.3750
# Epoch 00009: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2084 - accuracy: 0.5527 - val_loss: 1.3109 - val_accuracy: 0.4833
# Epoch 10/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.1579 - accuracy: 0.5648
# Epoch 00010: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1776 - accuracy: 0.5527 - val_loss: 1.2969 - val_accuracy: 0.4833
# Epoch 11/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.1803 - accuracy: 0.5463
# Epoch 00011: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1703 - accuracy: 0.5527 - val_loss: 1.2957 - val_accuracy: 0.4833
# Epoch 12/60
# 25/30 [========================>.....] - ETA: 0s - loss: 1.1484 - accuracy: 0.5450
# Epoch 00012: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1527 - accuracy: 0.5527 - val_loss: 1.2860 - val_accuracy: 0.4833
# Epoch 13/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.4074 - accuracy: 0.3750
# Epoch 00013: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.1414 - accuracy: 0.5527 - val_loss: 1.2805 - val_accuracy: 0.4833
# Epoch 14/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.1730 - accuracy: 0.5000
# Epoch 00014: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.1305 - accuracy: 0.5527 - val_loss: 1.3099 - val_accuracy: 0.4833
# Epoch 15/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.1519 - accuracy: 0.5463
# Epoch 00015: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.1363 - accuracy: 0.5527 - val_loss: 1.3556 - val_accuracy: 0.4833
# Epoch 16/60
# 29/30 [============================>.] - ETA: 0s - loss: 1.1352 - accuracy: 0.5517
# Epoch 00016: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1290 - accuracy: 0.5527 - val_loss: 1.2908 - val_accuracy: 0.4833
# Epoch 17/60
# 25/30 [========================>.....] - ETA: 0s - loss: 1.0831 - accuracy: 0.5550
# Epoch 00017: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0956 - accuracy: 0.5527 - val_loss: 1.2537 - val_accuracy: 0.4833
# Epoch 18/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.0807 - accuracy: 0.5602
# Epoch 00018: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0869 - accuracy: 0.5570 - val_loss: 1.2480 - val_accuracy: 0.4833
# Epoch 19/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.0640 - accuracy: 0.5648
# Epoch 00019: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0716 - accuracy: 0.5654 - val_loss: 1.2627 - val_accuracy: 0.4833
# Epoch 20/60
# 28/30 [===========================>..] - ETA: 0s - loss: 1.0583 - accuracy: 0.5893
# Epoch 00020: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0671 - accuracy: 0.5865 - val_loss: 1.2384 - val_accuracy: 0.4833
# Epoch 21/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.0621 - accuracy: 0.5787
# Epoch 00021: val_accuracy improved from 0.48333 to 0.50000, saving model to CNN_Model-21-0.50.h5
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0611 - accuracy: 0.5823 - val_loss: 1.2406 - val_accuracy: 0.5000
# Epoch 22/60
# 26/30 [=========================>....] - ETA: 0s - loss: 1.0748 - accuracy: 0.5721
# Epoch 00022: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0520 - accuracy: 0.5781 - val_loss: 1.2757 - val_accuracy: 0.5000
# Epoch 23/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.0441 - accuracy: 0.5787
# Epoch 00023: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0466 - accuracy: 0.5781 - val_loss: 1.2418 - val_accuracy: 0.5000
# Epoch 24/60
# 20/30 [===================>..........] - ETA: 0s - loss: 1.0591 - accuracy: 0.5688
# Epoch 00024: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0341 - accuracy: 0.5823 - val_loss: 1.2312 - val_accuracy: 0.5000
# Epoch 25/60
# 19/30 [==================>...........] - ETA: 0s - loss: 1.0208 - accuracy: 0.5987
# Epoch 00025: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0324 - accuracy: 0.5907 - val_loss: 1.2178 - val_accuracy: 0.4833
# Epoch 26/60
# 16/30 [===============>..............] - ETA: 0s - loss: 1.0024 - accuracy: 0.5781
# Epoch 00026: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0205 - accuracy: 0.5865 - val_loss: 1.2121 - val_accuracy: 0.4833
# Epoch 27/60
# 25/30 [========================>.....] - ETA: 0s - loss: 1.0164 - accuracy: 0.6050
# Epoch 00027: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0207 - accuracy: 0.6118 - val_loss: 1.2168 - val_accuracy: 0.4500
# Epoch 28/60
# 25/30 [========================>.....] - ETA: 0s - loss: 1.0677 - accuracy: 0.5750
# Epoch 00028: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0305 - accuracy: 0.5865 - val_loss: 1.2069 - val_accuracy: 0.4833
# Epoch 29/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8846 - accuracy: 0.6250
# Epoch 00029: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0090 - accuracy: 0.5865 - val_loss: 1.2090 - val_accuracy: 0.4833
# Epoch 30/60
# 29/30 [============================>.] - ETA: 0s - loss: 1.0055 - accuracy: 0.6207
# Epoch 00030: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0062 - accuracy: 0.6160 - val_loss: 1.2199 - val_accuracy: 0.4833
# Epoch 31/60
# 27/30 [==========================>...] - ETA: 0s - loss: 1.0016 - accuracy: 0.6157
# Epoch 00031: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9941 - accuracy: 0.6118 - val_loss: 1.2134 - val_accuracy: 0.4833
# Epoch 32/60
# 26/30 [=========================>....] - ETA: 0s - loss: 1.0467 - accuracy: 0.5817
# Epoch 00032: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9831 - accuracy: 0.6160 - val_loss: 1.2189 - val_accuracy: 0.5000
# Epoch 33/60
# 19/30 [==================>...........] - ETA: 0s - loss: 1.0108 - accuracy: 0.5724
# Epoch 00033: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0027 - accuracy: 0.5992 - val_loss: 1.2171 - val_accuracy: 0.5000
# Epoch 34/60
# 24/30 [=======================>......] - ETA: 0s - loss: 1.0013 - accuracy: 0.6094
# Epoch 00034: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9789 - accuracy: 0.6287 - val_loss: 1.1999 - val_accuracy: 0.5000
# Epoch 35/60
# 24/30 [=======================>......] - ETA: 0s - loss: 0.9801 - accuracy: 0.6250
# Epoch 00035: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9752 - accuracy: 0.6160 - val_loss: 1.1848 - val_accuracy: 0.4667
# Epoch 36/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.1934 - accuracy: 0.5000
# Epoch 00036: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9657 - accuracy: 0.6245 - val_loss: 1.1808 - val_accuracy: 0.5000
# Epoch 37/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.5611 - accuracy: 0.8750
# Epoch 00037: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9615 - accuracy: 0.6245 - val_loss: 1.1857 - val_accuracy: 0.5000
# Epoch 38/60
# 30/30 [==============================] - ETA: 0s - loss: 0.9688 - accuracy: 0.6203
# Epoch 00038: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9688 - accuracy: 0.6203 - val_loss: 1.1695 - val_accuracy: 0.5000
# Epoch 39/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.4464 - accuracy: 0.5000
# Epoch 00039: val_accuracy improved from 0.50000 to 0.51667, saving model to CNN_Model-39-0.52.h5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9577 - accuracy: 0.6329 - val_loss: 1.1973 - val_accuracy: 0.5167
# Epoch 40/60
# 25/30 [========================>.....] - ETA: 0s - loss: 0.9336 - accuracy: 0.6500
# Epoch 00040: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9559 - accuracy: 0.6245 - val_loss: 1.1878 - val_accuracy: 0.5000
# Epoch 41/60
# 11/30 [==========>...................] - ETA: 0s - loss: 0.9667 - accuracy: 0.6136
# Epoch 00041: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9529 - accuracy: 0.6371 - val_loss: 1.2588 - val_accuracy: 0.5000
# Epoch 42/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.2963 - accuracy: 0.5000
# Epoch 00042: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9673 - accuracy: 0.6118 - val_loss: 1.1640 - val_accuracy: 0.5000
# Epoch 43/60
# 27/30 [==========================>...] - ETA: 0s - loss: 0.9451 - accuracy: 0.6343
# Epoch 00043: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9456 - accuracy: 0.6329 - val_loss: 1.2077 - val_accuracy: 0.5167
# Epoch 44/60
# 30/30 [==============================] - ETA: 0s - loss: 0.9422 - accuracy: 0.6371
# Epoch 00044: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9422 - accuracy: 0.6371 - val_loss: 1.1509 - val_accuracy: 0.4833
# Epoch 45/60
# 26/30 [=========================>....] - ETA: 0s - loss: 0.9348 - accuracy: 0.6394
# Epoch 00045: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9327 - accuracy: 0.6329 - val_loss: 1.1611 - val_accuracy: 0.4833
# Epoch 46/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.0790 - accuracy: 0.5000
# Epoch 00046: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9342 - accuracy: 0.6329 - val_loss: 1.1755 - val_accuracy: 0.5167
# Epoch 47/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.0775 - accuracy: 0.6250
# Epoch 00047: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9431 - accuracy: 0.6245 - val_loss: 1.1736 - val_accuracy: 0.4833
# Epoch 48/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.1521 - accuracy: 0.6250
# Epoch 00048: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9304 - accuracy: 0.6414 - val_loss: 1.1758 - val_accuracy: 0.5167
# Epoch 49/60
# 30/30 [==============================] - ETA: 0s - loss: 0.9403 - accuracy: 0.6203
# Epoch 00049: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9403 - accuracy: 0.6203 - val_loss: 1.1474 - val_accuracy: 0.5000
# Epoch 50/60
# 27/30 [==========================>...] - ETA: 0s - loss: 0.8893 - accuracy: 0.6667
# Epoch 00050: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9242 - accuracy: 0.6414 - val_loss: 1.2157 - val_accuracy: 0.5167
# Epoch 51/60
# 26/30 [=========================>....] - ETA: 0s - loss: 0.9099 - accuracy: 0.6346
# Epoch 00051: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9399 - accuracy: 0.6203 - val_loss: 1.1573 - val_accuracy: 0.5000
# Epoch 52/60
# 25/30 [========================>.....] - ETA: 0s - loss: 0.9524 - accuracy: 0.6200
# Epoch 00052: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9160 - accuracy: 0.6329 - val_loss: 1.1954 - val_accuracy: 0.5167
# Epoch 53/60
# 30/30 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.6287
# Epoch 00053: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9185 - accuracy: 0.6287 - val_loss: 1.1310 - val_accuracy: 0.4833
# Epoch 54/60
# 29/30 [============================>.] - ETA: 0s - loss: 0.9028 - accuracy: 0.6336
# Epoch 00054: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9125 - accuracy: 0.6287 - val_loss: 1.1566 - val_accuracy: 0.4833
# Epoch 55/60
# 24/30 [=======================>......] - ETA: 0s - loss: 0.9086 - accuracy: 0.6406
# Epoch 00055: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9099 - accuracy: 0.6371 - val_loss: 1.1202 - val_accuracy: 0.4833
# Epoch 56/60
# 23/30 [======================>.......] - ETA: 0s - loss: 0.8856 - accuracy: 0.6630
# Epoch 00056: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9185 - accuracy: 0.6414 - val_loss: 1.1143 - val_accuracy: 0.4833
# Epoch 57/60
# 23/30 [======================>.......] - ETA: 0s - loss: 0.9157 - accuracy: 0.6087
# Epoch 00057: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9078 - accuracy: 0.6371 - val_loss: 1.1243 - val_accuracy: 0.4833
# Epoch 58/60
# 24/30 [=======================>......] - ETA: 0s - loss: 0.9476 - accuracy: 0.6146
# Epoch 00058: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9099 - accuracy: 0.6414 - val_loss: 1.1440 - val_accuracy: 0.4833
# Epoch 59/60
# 27/30 [==========================>...] - ETA: 0s - loss: 0.9070 - accuracy: 0.6435
# Epoch 00059: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9083 - accuracy: 0.6371 - val_loss: 1.1744 - val_accuracy: 0.5000
# Epoch 60/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.2388 - accuracy: 0.6250
# Epoch 00060: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9052 - accuracy: 0.6456 - val_loss: 1.1437 - val_accuracy: 0.5000

# %%
# Plotting the model
plt.plot(train_model.history['accuracy'], marker='.')
plt.plot(train_model.history['val_accuracy'], marker='.')
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
plt.savefig('model_accuracy.png')
plt.close()

plt.plot(train_model.history['loss'], marker='.')
plt.plot(train_model.history['val_loss'], marker='.')
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.savefig('model_loss.png')
plt.close()

# %%
pred = model.predict(X_test)

print('Maximum Probabilities of Test Dataset: ',np.max(pred, axis=-1))
# Out:
# Maximum Probabilities of Test Dataset:  [0.92982656 0.94296086 0.934381   0.5476818  0.59552157 0.3213791
#  0.58162946 0.2503766  0.5012551  0.8655031  0.24537219 0.27476177
#  0.27476177 0.8766711  0.92104095 0.97236055 0.7001706  0.5760018
#  0.8289416  0.65930563 0.850089   0.81192714 0.9680499  0.95790875
#  0.27476177 0.24724513 0.25791577 0.88838583 0.9293734  0.27476177
#  0.24825796 0.27476177 0.73300666 0.8936007  0.67444223 0.79103184
#  0.92801726 0.9003078  0.7919724  0.23917204 0.96616626 0.27476177
#  0.9755662  0.68972516 0.27476177 0.27476177 0.8084939  0.9500949
#  0.4945368  0.92929363 0.3004811  0.27476177 0.7907556  0.9860619
#  0.27476177 0.26288295 0.53432155 0.27476177 0.27476177 0.9422729 ]

# %%
for i in pred:
    if(np.max(i) > 0.8):
        print("Critical")
    elif(np.max(i) > 0.5):
        print("moderate or severe")
    elif(np.max(i) > 0.3):
        print("mild or moderate")
    else:
        print("None")
# Out:
# Critical
# Critical
# Critical
# moderate or severe
# moderate or severe
# mild or moderate
# moderate or severe
# None
# moderate or severe
# Critical
# None
# None
# None
# Critical
# Critical
# Critical
# moderate or severe
# moderate or severe
# Critical
# moderate or severe
# Critical
# Critical
# Critical
# Critical
# None
# None
# None
# Critical
# Critical
# None
# None
# None
# moderate or severe
# Critical
# moderate or severe
# moderate or severe
# Critical
# Critical
# moderate or severe
# None
# Critical
# None
# Critical
# moderate or severe
# None
# None
# Critical
# Critical
# mild or moderate
# Critical
# mild or moderate
# None
# moderate or severe
# Critical
# None
# None
# moderate or severe
# None
# None
# Critical

# %%
# need to take argmax if it is a multiclass problem
y_pred = np.argmax(pred, axis=1)
y_test = np.argmax(y_test, axis=1)


print('Classification Accuracy: '+str(accuracy_score(y_test, y_pred) * 100)+' %')
# Out:
# Classification Accuracy: 50.0 %
